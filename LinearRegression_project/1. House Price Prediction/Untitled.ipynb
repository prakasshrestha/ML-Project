# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import kagglehub
#       3 # Download latest version
#       4 path = kagglehub.dataset_download("sagyamthapa/nepali-housing-price-dataset")
#
# ModuleNotFoundError: No module named 'kagglehub'
