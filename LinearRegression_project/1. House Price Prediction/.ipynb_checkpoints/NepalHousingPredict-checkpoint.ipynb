# %%
import pandas as pd
import numpy as np

# %%
# read the dataset Nepal housing dataset
dataset = pd.read_csv("./Dataset/2020-4-27.csv")
dataset.head()
# Out:
#                                                Title  \
# 0  Flat System House On Sale At Budhanikantha : H...
# 1  21 Aana Beautiful House : House For Sale In Bu...
# 2  Beautiful To Floor House : House For Sale In D...
# 3  Modern Architecture Bungalow House : House For...
# 4  Modern Bungalow House : House For Sale In Golf...
#
#                                     Address       City      Price  Bedroom  \
# 0  Budhanikantha, Budhanilkantha, Kathmandu  Kathmandu   90000000        6
# 1        Pasikot, Budhanilkantha, Kathmandu  Kathmandu   80000000        5
# 2               Dhapasi, Dhapasi, Kathmandu  Kathmandu   70000000        5
# 3           baluwatar, Baluwatar, Kathmandu  Kathmandu  130000000        6
# 4             Golfutar, Golfutar, Kathmandu  Kathmandu  100000000        6
#
#    Bathroom  Floors  Parking  Face    Year Views           Area  \
# 0         3     2.0       10  West  2073.0    17   1-0-0-0 Aana
# ...

# %%
dataset['Title']
# Out:
# 0       Flat System House On Sale At Budhanikantha : H...
# 1       21 Aana Beautiful House : House For Sale In Bu...
# 2       Beautiful To Floor House : House For Sale In D...
# 3       Modern Architecture Bungalow House : House For...
# 4       Modern Bungalow House : House For Sale In Golf...
#                               ...
# 2206                 House For Rent In Chapali, Kathmandu
# 2207               House For Sale In Sitapaila, Kathmandu
# 2208          House For Sale In Budhanilkantha, Kathmandu
# 2209               House For Rent In Baneshwor, Kathmandu
# 2210               House For Sale In Baluwatar, Kathmandu
# Name: Title, Length: 2211, dtype: object

# %%
dataset.iloc[3]['Title']
# Out:
# 'Modern Architecture Bungalow House : House For Sale In Baluwatar, Kathmandu'

# %%
dataset.iloc[3]
# Out:
# Title         Modern Architecture Bungalow House : House For...
# Address                         baluwatar, Baluwatar, Kathmandu
# City                                                  Kathmandu
# Price                                                 130000000
# Bedroom                                                       6
# Bathroom                                                      4
# Floors                                                      3.0
# Parking                                                       9
# Face                                                       West
# Year                                                     2017.0
# Views                                                        17
# Area                                              0-10-1-0 Aana
# Road                                      20 Feet / Blacktopped
# Road Width                                             20 Feet
# Road Type                                           Blacktopped
# ...

# %%
dataset['Title'].value_counts()
# Out:
# Title
# House For Sale In Imadol, Lalitpur                                     38
# House For Sale In Budhanilkantha, Kathmandu                            38
# Land For Sale In Budhanilkantha, Kathmandu                             33
# House For Sale In Kapan, Kathmandu                                     17
# House For Sale In Basundhara, Kathmandu                                16
#                                                                        ..
# Apartment At 4th Floor : Apartment For Sale In Bhaisepati, Lalitpur     1
# Apartment For Sale : Apartment For Sale In Bhaisepati, Lalitpur         1
# 2.5 Storey House : House For Sale In Lokanthali, Bhaktapur              1
# 2.5 Storey House : House For Sale In Budhanilkantha, Kathmandu          1
# House For Rent In Chapali, Kathmandu                                    1
# Name: count, Length: 1502, dtype: int64
